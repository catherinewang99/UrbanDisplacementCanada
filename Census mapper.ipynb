# %%
import pandas as pd
import numpy as np

# %%
# %load_ext rpy2.ipython

# %%
# %%R
#
#
# install.packages("cancensus")
# library(cancensus)
# options(cancensus.api_key='CensusMapper_8d89aaa158834f59c772961625b3a427')
# # options(cancensus.cache_path = <your long term cache path>)
#
# census_data <- get_census(dataset='CA16', regions=list(CSD="5915022"), vectors=c("v_CA16_2397","v_CA16_2345","v_CA16_5096","v_CA16_4895","v_CA16_4893","v_CA16_4900","v_CA16_404","v_CA16_4836","v_CA16_4862","v_CA16_401","v_CA16_4","v_CA16_61","v_CA16_244","v_CA16_1","v_CA16_6692","v_CA16_6719"), labels="detailed", geo_format=NA, level='CT')
# Out:
# --- Please select a CRAN mirror for use in this session ---
#
#   There is a binary version available but the source version is later:
#           binary source needs_compilation
# cancensus  0.2.1  0.4.2             FALSE
# R[write to console]: installing the source package ‘cancensus’
#
#
# R[write to console]: trying URL 'https://ftp.osuosl.org/pub/cran/src/contrib/cancensus_0.4.2.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 917643 bytes (896 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# ...

# %%
install.packages("cancensus")
library(cancensus)
options(cancensus.api_key='CensusMapper_8d89aaa158834f59c772961625b3a427')
# options(cancensus.cache_path = <your long term cache path>)

census_data_1 <- get_census(dataset='CA16', regions=list(CSD="5915022"), vectors=c("v_CA16_2357","v_CA16_2360","v_CA16_2366","v_CA16_2369","v_CA16_2372","v_CA16_2375","v_CA16_2378","v_CA16_2381","v_CA16_2387","v_CA16_2363","v_CA16_2393","v_CA16_2390","v_CA16_5120","v_CA16_5111","v_CA16_5114","v_CA16_5117","v_CA16_5099","v_CA16_5102","v_CA16_5126","v_CA16_5129","v_CA16_5132","v_CA16_5135","v_CA16_5138","v_CA16_4863","v_CA16_4864","v_CA16_4865","v_CA16_4866","v_CA16_4867","v_CA16_4868","v_CA16_4869","v_CA16_4837","v_CA16_4838","v_CA16_4839","v_CA16_385","v_CA16_388","v_CA16_391","v_CA16_394","v_CA16_6695","v_CA16_6698","v_CA16_6701","v_CA16_6704","v_CA16_6707","v_CA16_6710","v_CA16_6713","v_CA16_6716","v_CA16_6722","v_CA16_6725","v_CA16_6728","v_CA16_6731","v_CA16_6734","v_CA16_6737","v_CA16_6740","v_CA16_6743"), labels="detailed", geo_format=NA, level='CT')

# %%
# %%R -o census_data_1
#
# census_data_1

# %%
# %%R -o census_data
#
# census_data
# Out:
# # A tibble: 117 x 27
#    GeoUID     Type  `Region Name` `Area (sq km)` Population Dwellings Households
#    <chr>      <fct> <fct>                  <dbl>      <dbl>     <dbl>      <dbl>
#  1 9330001.01 CT    Vancouver              1.02        6293      2334       2314
#  2 9330001.02 CT    Vancouver              2.03        5456      2132       2089
#  3 9330002.01 CT    Vancouver              2.03        6150      2631       2507
#  4 9330002.03 CT    Vancouver              0.785       4077      1497       1292
#  5 9330002.04 CT    Vancouver              0.845       4509      1652       1560
#  6 9330003.01 CT    Vancouver              0.543       3714      1210       1080
#  7 9330003.02 CT    Vancouver              1.20        4613      1429       1316
#  8 9330004.01 CT    Vancouver              1.63        4925      2537       1928
#  9 9330004.02 CT    Vancouver              1.25        5652      1847       1689
# ...

# %%
census_data
# Out:
#          GeoUID Type Region Name  Area (sq km)  Population  Dwellings  \
# 1    9330001.01   CT   Vancouver       1.01953      6293.0     2334.0
# 2    9330001.02   CT   Vancouver       2.02898      5456.0     2132.0
# 3    9330002.01   CT   Vancouver       2.02909      6150.0     2631.0
# 4    9330002.03   CT   Vancouver       0.78516      4077.0     1497.0
# 5    9330002.04   CT   Vancouver       0.84513      4509.0     1652.0
# ..          ...  ...         ...           ...         ...        ...
# 113  9330065.00   CT   Vancouver       0.24101      7147.0     4801.0
# 114  9330066.00   CT   Vancouver       0.52863      8639.0     5910.0
# 115  9330067.01   CT   Vancouver       0.18628      3772.0     2633.0
# 116  9330067.02   CT   Vancouver       0.23530      4773.0     3016.0
# 117  9330068.00   CT   Vancouver       4.27161      5085.0     3662.0
#
#      Households CMA_UID PR_UID  CSD_UID  ...  \
# 1        2314.0   59933     59  5915022  ...
# ...

# %%
# census_data.to_csv('vancouver2016.csv')

# %%
vancouver1996 = pd.read_csv('ct_data_1996_Vancouver.csv')
vancouver1996
# Out:
#     Unnamed: 0  Unnamed: 1 CT Name CT Code Population 1996 (100% data)  25-29  \
# 0       CMA/CA       CTUID      V1      V2                          V9    V24
# 1          933     9330000       0       0                     1831665  75725
# 2          933     9330003       3    2230                        7570    340
# 3          933     9330004       4    2231                        8774    410
# 4          933     9330005       5    2232                        6553    530
# ..         ...         ...     ...     ...                         ...    ...
# 295        933  9330189.04  189.04    4900                        7862    260
# 296        933  9330140.01  140.01    4901                        7513    320
# 297        933  9330140.02  140.02    4902                        4610     80
# 298        933  9330001.01    1.01    4903                        6420    165
# 299        933  9330001.02    1.02    4904                        3844    120
#
# ...
